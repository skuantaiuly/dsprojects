# %%
import pandas as pd
import seaborn as sb; sb.set()
import numpy as np
# %matplotlib inline
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data
# Out:
#               x           y  color
# 0    516.012706  393.014514      0
# 1    436.211762  408.656585      0
# 2    512.052601  372.022014      0
# 3    489.140464  401.807159      0
# 4    446.207986  338.516682      0
# ..          ...         ...    ...
# 331  638.916471  323.569096      1
# 332  542.005901  347.527070      0
# 333  611.964612  377.254978      0
# 334  520.654168  455.996453      0
# 335  594.479314  392.901455      0
#
# [336 rows x 3 columns]

# %%
x = list(data['x'])
y = list(data['y'])
color = list(data['color'])

# %%
plt.scatter(x,y,s=20)
plt.show()

# %%
arr2d = np.column_stack([x,y])
arr2d
# Out:
# array([[516.01270584, 393.01451385],
#        [436.21176221, 408.65658486],
#        [512.05260123, 372.02201357],
#        [489.14046445, 401.80715936],
#        [446.20798589, 338.51668221],
#        [516.41439428, 354.1946332 ],
#        [499.38635309, 414.43229606],
#        [489.31393714, 408.06659564],
#        [440.10939244, 394.82167659],
#        [444.11917081, 367.85030508],
#        [430.85313667, 364.04631808],
#        [462.7448851 , 411.33745082],
#        [525.39083505, 344.24685087],
#        [489.98703991, 366.08045501],
#        [513.90668815, 378.01799727],
#        [485.21289498, 347.67383973],
#        [529.120055  , 359.84631868],
#        [518.68713041, 382.72155663],
#        [464.54999431, 317.79936551],
#        [489.13628727, 322.48179143],
#        [517.03910049, 359.49949992],
#        [501.92408395, 406.57937627],
#        [517.32718213, 407.19390734],
#        [482.41870028, 402.3376873 ],
#        [502.80582424, 348.77041754],
# ...

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(arr2d)
y_kmeans = kmeans.predict(arr2d)

# %%
plt.figure(figsize=(8,6))
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=3)')
plt.scatter(arr2d[:, 0], arr2d[:, 1], c = color, s = 50, cmap='Set1')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c ='black', s=100 )
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.xlabel('x')
plt.ylabel('y')
plt.title('Clustered data (k=3)')
plt.scatter(arr2d[:, 0], arr2d[:, 1], c = y_kmeans, s = 50, cmap='Set1')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c ='black', s=100 )
plt.show()
